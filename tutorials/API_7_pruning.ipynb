# %% [markdown]
# # Demo 7: Pruning
#
# We usually use pruning to make neural networks sparser hence more efficient and more interpretable. KANs provide two ways of pruning: automatic pruning, and manual pruning.

# %% [markdown]
# ## Pruning nodes

# %%
from kan import *
# create a KAN: 2D inputs, 1D output, and 5 hidden neurons. cubic spline (k=3), 5 grid intervals (grid=5).
model = KAN(width=[2,5,1], grid=5, k=3, seed=1)

# create dataset f(x,y) = exp(sin(pi*x)+y^2)
f = lambda x: torch.exp(torch.sin(torch.pi*x[:,[0]]) + x[:,[1]]**2)
dataset = create_dataset(f, n_var=2)
dataset['train_input'].shape, dataset['train_label'].shape

# train the model
model.fit(dataset, opt="LBFGS", steps=20, lamb=0.01);
model(dataset['train_input'])
model.plot()
# Out:
# train loss: 4.42e-02 | test loss: 4.54e-02 | reg: 5.27e+00 : 100%|██| 20/20 [00:03<00:00,  6.36it/s]

# %%
mode = 'auto'

if mode == 'auto':
    # automatic
    model = model.prune_node(threshold=1e-2) # by default the threshold is 1e-2
    model.plot()
elif mode == 'manual':
    # manual
    model = model.prune_node(active_neurons_id=[[0]])

# %% [markdown]
# ## Pruning Edges

# %%
from kan import *
# create a KAN: 2D inputs, 1D output, and 5 hidden neurons. cubic spline (k=3), 5 grid intervals (grid=5).
model = KAN(width=[2,5,1], grid=5, k=3, seed=1)

# create dataset f(x,y) = exp(sin(pi*x)+y^2)
f = lambda x: torch.exp(torch.sin(torch.pi*x[:,[0]]) + x[:,[1]]**2)
dataset = create_dataset(f, n_var=2)
dataset['train_input'].shape, dataset['train_label'].shape

# train the model
model.fit(dataset, opt="LBFGS", steps=6, lamb=0.01);
model(dataset['train_input'])
model.plot()
# Out:
# train loss: 5.03e-02 | test loss: 5.11e-02 | reg: 6.26e+00 : 100%|████| 6/6 [00:01<00:00,  5.63it/s]

# %%
model.prune_edge()

# %%
model.plot()

# %% [markdown]
# ## Prune nodes and edges together

# %% [markdown]
# just use model.prune()

# %%
from kan import *
# create a KAN: 2D inputs, 1D output, and 5 hidden neurons. cubic spline (k=3), 5 grid intervals (grid=5).
model = KAN(width=[2,5,1], grid=5, k=3, seed=1)

# create dataset f(x,y) = exp(sin(pi*x)+y^2)
f = lambda x: torch.exp(torch.sin(torch.pi*x[:,[0]]) + x[:,[1]]**2)
dataset = create_dataset(f, n_var=2)
dataset['train_input'].shape, dataset['train_label'].shape

# train the model
model.fit(dataset, opt="LBFGS", steps=20, lamb=0.01);
model(dataset['train_input'])
model.plot()
# Out:
# train loss: 4.42e-02 | test loss: 4.54e-02 | reg: 5.27e+00 : 100%|██| 20/20 [00:03<00:00,  6.36it/s]

# %%
model = model.prune()
model.plot()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 model = model.prune()
#       2 model.plot()
#
# File ~/Desktop/Project AI MODELS/kan/MultKAN.py:975, in MultKAN.prune(self, node_th, edge_th)
#     973 self.attribute()
#     974 self.prune_edge(edge_th, log_history=False)
# --> 975 self.log_history('prune')
#     976 return self
#
# File ~/Desktop/Project AI MODELS/kan/MultKAN.py:183, in MultKAN.log_history(self, method_name)
#     177 def log_history(self, method_name):
#     179     if self.auto_save:
#     180
#     181         # save to log file
#     182         #print(func.__name__)
# --> 183         with open(self.ckpt_path+'/history.txt', 'a') as file:
#     184             file.write(str(self.state_id)+' => '+ method_name + ' => ' + str(self.state_id+1) + '\n')
#     186         # update state_id
#
# FileNotFoundError: [Errno 2] No such file or directory: './model/history.txt'
